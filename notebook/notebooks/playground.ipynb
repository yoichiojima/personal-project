# %%
import sys
sys.path.append('/app')
from libs import spotipy_auth
spotipy_auth()
import pandas as pd

# %%
from pprint import pprint

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def categories():
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

    result = spotify.categories(limit = 50, country = 'US')

    df = pd.DataFrame(result['categories']['items'])
    
    return df[['id', 'name']]

categories().head()
# Out:
#                        id       name
# 0                toplists  Top Lists
# 1                  hiphop    Hip-Hop
# 2  0JQ5DAqbMKFEC4WFtoNRpw        Pop
# 3  0JQ5DAqbMKFKLfwjuJMoNC    Country
# 4  0JQ5DAqbMKFxXaXKP7zcDp      Latin

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def query_new_releases():
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

    result = spotify.new_releases(country = 'US', limit = 50)

    df = pd.DataFrame(result['albums']['items'])
    df = df.copy()
    df['artists_name'] = df['artists'].apply(lambda row: [artist['name'] for artist in row])
    df['artists_id'] = df['artists'].apply(lambda row: [artist['id'] for artist in row])
    
    return df[['album_type', 
               'artists_name', 
               'name', 
               'release_date', 
               'total_tracks', 
               'id',
               'artists_id']]

query_new_releases().head()
# Out:
#   album_type        artists_name                name release_date  \
# 0      album      [Taylor Swift]           Midnights   2022-10-21
# 1      album    [Arctic Monkeys]             The Car   2022-10-21
# 2     single       [Roddy Ricch]  Aston Martin Truck   2022-10-21
# 3      album  [Spencer Crandall]             Western   2022-10-21
# 4      album    [Meghan Trainor]      Takin' It Back   2022-10-21
#
#    total_tracks                      id                artists_id
# 0            13  151w1FgRZfnKZA9FEcg9Z3  [06HL4z0CvFAxyc27GXpf02]
# 1            10  1kqHAucTGT1dJAtNXY8QDW  [7Ln80lUS6He07XvHI8qqHH]
# 2             1  4Uv7QjKaAq1mFO7aYzk4Xc  [757aE44tKEUQEqRuT6GnEB]
# 3            20  5CbbfVTtYGmnVn6rLrgklf  [6to2NJmRWY1h7rLU4c9TyG]
# 4            16  4ARAitcMTM2eGbZE1Hp9fq  [6JL8zeS1NmiOftqZTRgdTz]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

artist_id = "53KwLdlmrlCelAZMaLVZqU"

def query_artist(artist_id):
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

    result = spotify.artist_related_artists(artist_id)

    df = pd.DataFrame(result['artists'])

    df = df[['name',
             'followers',
             'genres',
             'popularity',
             'id']]

    df = df.copy()
    df['followers'] = df['followers'].apply(lambda row: row['total'])
    return df

query_artist(artist_id).head()
# Out:
#               name  followers  \
# 0     Mount Kimbie     295083
# 1           Burial     383004
# 2           SBTRKT     625935
# 3         Jamie xx     718142
# 4  Floating Points     275122
#
#                                               genres  popularity  \
# 0  [chillwave, electra, electronica, future garag...          53
# 1  [classic dubstep, electronica, hauntology, int...          52
# 2  [electronica, electropop, future garage, new r...          50
# 3  [alternative dance, electronica, future garage...          62
# 4                 [electronica, microhouse, uk bass]          52
#
#                        id
# 0  3NUtpWpGDoffm3RCGhSHtl
# 1  0uCCBpmg6MrPb1KY2msceF
# 2  1O10apSOoAPjOu6UhUNmeI
# 3  7A0awCXkE1FtSU8B0qwOJQ
# 4  2AR42Ur9PcchQDtEdwkv4L

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def query_top_playlists():
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

    result = spotify.category_playlists(category_id = 'toplists', limit = 50, country = 'US')

    df = pd.DataFrame(result['playlists']['items'])
    
    return df[['name', 'description', 'id']]

query_top_playlists()
# Out:
#                  name                                        description  \
# 0    Today's Top Hits          Taylor Swift is on top of the Hottest 50!
# 1           RapCaviar  New music from Lil Uzi Vert, Roddy Ricch and A...
# 2           Rock This  The new single from Måneskin along with the Ro...
# 3                mint  The world's biggest dance hits. Cover: Seven L...
# 4         Hot Country  Today's top country hits of the week, worldwid...
# 5         Viva Latino  Today's top Latin hits, elevando nuestra músic...
# 6            Are & Be    The pulse of R&B music today.  Cover: NxWorries
# 7        Top 50 - USA  Your daily update of the most played tracks ri...
# 8     Top 50 - Global  Your daily update of the most played tracks ri...
# 9   Viral 50 - Global  Your daily update of the most viral tracks rig...
# 10     Viral 50 - USA  Your daily update of the most viral tracks rig...
# 11   New Music Friday  New music from Taylor Swift, Arctic Monkeys, L...
#
#                         id
# 0   37i9dQZF1DXcBWIGoYBM5M
# 1   37i9dQZF1DX0XUsuxWHRQd
# 2   37i9dQZF1DXcF6B6QPhFDv
# 3   37i9dQZF1DX4dyzvuaRJ0n
# 4   37i9dQZF1DX1lVhptIYRda
# 5   37i9dQZF1DX10zKzsJ2jva
# 6   37i9dQZF1DX4SBhb3fqCJd
# 7   37i9dQZEVXbLRQDuF5jeBp
# 8   37i9dQZEVXbMDoHDwVN2tF
# 9   37i9dQZEVXbLiRSasKsNU9
# 10  37i9dQZEVXbKuaTI1Z1Afx
# 11  37i9dQZF1DX4JAvHpjipBk

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def query_top_50_global():
    spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

    result = spotify.playlist_tracks(playlist_id = '37i9dQZEVXbMDoHDwVN2tF', limit = 50)
    
    df = pd.DataFrame(result['items'])
    df = df[['added_at',
             'track']]

    df = df.copy()
    df['track_id'] = df['track'].apply(lambda row: row['id'])

    df['track_name'] = df['track'].apply(lambda row: row['name'])
    df['artists_id'] = df['track'].apply(lambda row: [artist['id'] for artist in row['artists']])
    df['artists_name'] = df['track'].apply(lambda row: [artist['name'] for artist in row['artists']])

    return df[['track_name', 
              'artists_name', 
              'added_at',
              'track_id', 
              'artists_id']]

query_top_50_global()
# Out:
#                                 track_name                   artists_name  \
# 0                                Anti-Hero                 [Taylor Swift]
# 1                Unholy (feat. Kim Petras)        [Sam Smith, Kim Petras]
# 2                            Lavender Haze                 [Taylor Swift]
# 3                            Midnight Rain                 [Taylor Swift]
# 4   Snow On The Beach (feat. Lana Del Rey)   [Taylor Swift, Lana Del Rey]
# 5                                   Maroon                 [Taylor Swift]
# 6                  You're On Your Own, Kid                 [Taylor Swift]
# 7                                    Karma                 [Taylor Swift]
# 8                                Bejeweled                 [Taylor Swift]
# 9                           Vigilante Shit                 [Taylor Swift]
# 10                            Question...?                 [Taylor Swift]
# 11                         I'm Good (Blue)     [David Guetta, Bebe Rexha]
# 12                               As It Was                 [Harry Styles]
# 13                              La Bachata                [Manuel Turizo]
# 14                              Mastermind                 [Taylor Swift]
# 15   Quevedo: Bzrp Music Sessions, Vol. 52            [Bizarrap, Quevedo]
# 3                           [06HL4z0CvFAxyc27GXpf02]
# 4   [06HL4z0CvFAxyc27GXpf02, 00FQb4jTyendYWaN8pK0wa]
# 5                           [06HL4z0CvFAxyc27GXpf02]
# 6                           [06HL4z0CvFAxyc27GXpf02]
# 7                           [06HL4z0CvFAxyc27GXpf02]
# 8                           [06HL4z0CvFAxyc27GXpf02]
# 9                           [06HL4z0CvFAxyc27GXpf02]
# 10                          [06HL4z0CvFAxyc27GXpf02]
# 11  [1Cs0zKBU1kc0i8ypK3B9ai, 64M6ah0SkkRsnPGtGiRAbb]
# 12                          [6KImCVD70vtIoJWnq6nGn3]
# 13                          [0tmwSHipWxN12fsoLcFU3B]
# 14                          [06HL4z0CvFAxyc27GXpf02]
# 15  [716NhGYqD1jl2wI1Qkgq36, 52iwsT98xCoGgiGntTiR7K]
# 16                          [06HL4z0CvFAxyc27GXpf02]
# 17                          [06HL4z0CvFAxyc27GXpf02]
# 18                          [7bXgB6jMjp9ATFy66eO08Z]
# 19                          [5Pwc4xIPtQLFEnJriah9YJ]
# 20  [4q3ewBCX7sLwd24euuV69X, 37230BxxYs9ksS7OkZw3IU]
# 21                          [4q3ewBCX7sLwd24euuV69X]
# 22                          [57vWImR43h4CaDao012Ofp]
# 23                          [06HL4z0CvFAxyc27GXpf02]
# 24  [0EmeFodog0BfCgMzAIvKQp, 1i8SpTcr7yvPOmcqrbnVXY]
# 25                          [7ltDVBr6mKbRvohxheJ9h1]
# 26                          [2txHhyCwHjUEpJjWrEyqyX]
# 27                          [6vWDO969PvNqNYHIOW5v0m]
# 28  [6TLwD7HPWuiOzvXEa3oCNe, 3t5xRXzsuZmMDkQzgOX35S]
# 29                          [4q3ewBCX7sLwd24euuV69X]
# 30                          [46xBNx0j6cwY6sD9LgMTm1]
# 31                          [5y8tKLUfMvliMe8IKamR32]
# 32                          [06HL4z0CvFAxyc27GXpf02]
# 33                          [06HL4z0CvFAxyc27GXpf02]
# 34                          [164Uj4eKjl6zTBKfJLFKKK]
# 35                          [5XKFrudbV4IiuE5WuTPRmT]
# 36                          [77SW9BnxLY8rJ0RciFqkHh]
# 37  [46pWGuE3dSwY3bMMXGBvVS, 0C8ZW7ezQVs4URX5aX7Kqx]
# 38                          [53XhwfbYqKCa1cC15pYq2q]
# 39  [4q3ewBCX7sLwd24euuV69X, 5n9bMYfz9qss2VOW89EVs2]
# 40                          [06HL4z0CvFAxyc27GXpf02]
# 41                          [7Ln80lUS6He07XvHI8qqHH]
# 42                          [1Xyo4u8uXC1ZmMpatF05PJ]
# 43                          [3MZsBdqDrRTJihTHQrO6Dq]
# 44                          [41MozSoPIsD1dJM0CLPjZF]
# 45                          [06HL4z0CvFAxyc27GXpf02]
# 46                          [4yvcSjfu4PC0CYQyLy4wSq]
# 47                          [0hCNtLu0JehylgoiP8L4Gh]
# 48                          [4q3ewBCX7sLwd24euuV69X]
# 49  [1i8SpTcr7yvPOmcqrbnVXY, 2LRoIwlKmHjgvigdNGBHNo]
